# %%
# !git config --global user.name "udvotttechnologist"
# !git config --global user.email "tonmoypaul0055@gmail.com"

# %%
# !git clone https://github.com/udvotttechnologist/NASAPowerProcessor.git
# Out:
# Cloning into 'NASAPowerProcessor'...
# fatal: could not read Username for 'https://github.com': No such device or address
